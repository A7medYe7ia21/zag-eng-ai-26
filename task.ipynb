# %%
print("we are not the same")
# Out:
# we are not the same

# %%
a=3
b=5
print(a//b)
print(a/b)
# Out:
# 0
# 0.6

# %%
with open("data.txt", "r") as file:
    content = file.read()
    print(content)

# %%
a=7
b=5
print(a+b)
print(a-b)
print(a*b)
# Out:
# 8
# -2
# 15
